# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import math

# %%
Vm = np.arange(0.1,20,0.1)

a0 = 1
a1 = 10
a2 = -1
a3 = -2

# %%
#Graphically
Vout_fund_ideal_20log = 20*np.log(Vm) + 20*np.log(a1)    #Eq1
Vm_IM3 = (3/4)*a3*Vm*3
Vm_IM3_20log = 20*np.log(abs(Vm_IM3))                    #Eq2

plt.plot(20*np.log(Vm),Vout_fund_ideal_20log)
plt.plot(20*np.log(Vm),Vm_IM3_20log)

# %%
#formula
Vm_form = np.sqrt((4/3)*abs(a1/a3))
plt.scatter(20*np.log(Vm_form),20*np.log(Vm_form) + 20*np.log(a1))
